# %% [markdown]
# <a href="https://colab.research.google.com/github/hikariiiyy/sistem-panen-2/blob/main/fitur%20input.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Sistem Pencatatan Hasil Panen")
def input_data():
    nama = input("Nama komoditas: ")
    jumlah = float(input("Jumlah (kg): "))
    return nama, jumlah
# Out:
# Sistem Pencatatan Hasil Panen
